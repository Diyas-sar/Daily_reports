# %% [markdown]
# <a href="https://colab.research.google.com/github/Diyas-sar/Daily_reports/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data = pd.read_excel('/content/Export.xlsx')
data
# Out:
#           Дата             Тип операции   \
# 0    2023-12-04                 Комиссия
# 1    2023-12-04                 Комиссия
# 2    2023-12-04                 Комиссия
# 3    2023-11-06  Перевод внутри компании
# 4    2023-11-03                 Комиссия
# ..          ...                      ...
# 873  2019-01-28      Комиссия за сделки
# 874  2019-01-28      Комиссия за сделки
# 875  2019-01-28      Комиссия за сделки
# 876  2019-01-24      Комиссия за сделки
# 877  2019-01-21       Банковский перевод
#
#                                           Комментарий     Сумма   Валюта
# 0                  December options level 1 (DTAPP098)    -15.00      USD
# 1                     December platform fee (DTAPP098)    -25.00      USD
# 2                    December platform fee (DTWEB2356)     -5.00      USD
# 3                             wire transfer to D020350     -0.08      USD
# 4                    November platform fee (DTWEB2356)     -5.00      USD
# ...

# %%
#коммисия за сделки
df_commision_deal = data[data[' Тип операции '] == ' Комиссия за сделки ']
print(df_commision_deal[' Сумма '].sum())
#коммисия
df_commision_platform = data[data[' Тип операции '] == 'Комиссия']
print(df_commision_platform[' Сумма '].sum())
# Out:
# -16197.25
# -2695.0

# %%
df_index = data[data[' Дата '] == '2021-01-04']['Index']
df_index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Index'
#
# The above exception was the direct cause of the following exception:
#
# ...
